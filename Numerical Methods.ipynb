% %% [markdown]
% ### TODO :
% * Add 'et' variable
% * Check f(a) , f(b) for Bisection and Regula Falsi Method
% * er -> ea

% %% [markdown]
% ## Bisection Method Iteration

% %%
f = @(x) sin(x) - (x/2)^2;
iteration = 10;
tr = 1;
a = 1; 
b = 2;
ea = 100;
et = 100;
printf("itr\t a\t\t b\t\t x\t\t f(x)\t\t ea\t\t et\n");
for i = 1 : iteration
    fa = f(a);
    fb = f(b);
    mid = (a+b)/2;
    fm = f(mid);
    if(fm*fa>0)
    % Check mid != 0
        ea = abs((mid-a)/mid)*100;
        et = abs((tr-mid)/tr)*100;
        printf("%d\t %f\t %f\t %f\t %f\t %f\t %f\n",i,a,b,mid,fm,ea,et);
        a = mid;
    elseif (fb*fm>0)
        ea = abs((mid-b)/mid)*100;
        et = abs((tr-mid)/tr)*100;
        printf("%d\t %f\t %f\t %f\t %f\t %f\t %f\n",i,a,b,mid,fm,ea,et);
        b = mid;
    endif
endfor
% Out:
% fa =  0.59147
% fa = -0.090703
% itr	 a		 b		 x		 f(x)		 ea		 et
% 1	 1.000000	 2.000000	 1.500000	 0.434995	 33.333333	 50.000000
% 2	 1.500000	 2.000000	 1.750000	 0.218361	 14.285714	 75.000000
% 3	 1.750000	 2.000000	 1.875000	 0.075180	 6.666667	 87.500000
% 4	 1.875000	 2.000000	 1.937500	 -0.004962	 3.225806	 93.750000
% 5	 1.875000	 1.937500	 1.906250	 0.035814	 1.639344	 90.625000
% 6	 1.906250	 1.937500	 1.921875	 0.015601	 0.813008	 92.187500
% 7	 1.921875	 1.937500	 1.929688	 0.005363	 0.404858	 92.968750
% 8	 1.929688	 1.937500	 1.933594	 0.000212	 0.202020	 93.359375
% 9	 1.933594	 1.937500	 1.935547	 -0.002373	 0.100908	 93.554688
% 10	 1.933594	 1.935547	 1.934570	 -0.001080	 0.050480	 93.457031

% %% [markdown]
% ## Bisection II

% %%
f = @(x) sin(x) - (x/2)^2;
e = 0.01;
a = 1;
b = 2;
ea = 100;
while e<ea
fa = f(a);
fb = f(b);
mid = (a+b)/2;
fm = f(mid);
if(fa == 0)
    a;
    ea = 0;
elseif (fb == 0)
    b;
    ea = 0;
elseif(mid == 0)
    mid;
    ea = 0;
endif

if (fm*fa>0)
    ea = abs((mid - a)/mid * 100);
    printf("a = %f b = %f mid = %f fmid = %f ea = %f\n",a,b,mid,fm,ea);
    a = mid;
elseif (fm*fb>0)
    ea = abs((b-mid)/mid * 100);
    printf("a = %f b = %f mid = %f fmid = %f ea = %f\n",a,b,mid,fm,ea);
    b = mid;

endif
endwhile
% Out:
% a = 1.000000 b = 2.000000 mid = 1.500000 fmid = 0.434995 ea = 33.333333
% a = 1.500000 b = 2.000000 mid = 1.750000 fmid = 0.218361 ea = 14.285714
% a = 1.750000 b = 2.000000 mid = 1.875000 fmid = 0.075180 ea = 6.666667
% a = 1.875000 b = 2.000000 mid = 1.937500 fmid = -0.004962 ea = 3.225806
% a = 1.875000 b = 1.937500 mid = 1.906250 fmid = 0.035814 ea = 1.639344
% a = 1.906250 b = 1.937500 mid = 1.921875 fmid = 0.015601 ea = 0.813008
% a = 1.921875 b = 1.937500 mid = 1.929688 fmid = 0.005363 ea = 0.404858
% a = 1.929688 b = 1.937500 mid = 1.933594 fmid = 0.000212 ea = 0.202020
% a = 1.933594 b = 1.937500 mid = 1.935547 fmid = -0.002373 ea = 0.100908
% a = 1.933594 b = 1.935547 mid = 1.934570 fmid = -0.001080 ea = 0.050480
% a = 1.933594 b = 1.934570 mid = 1.934082 fmid = -0.000434 ea = 0.025246
% a = 1.933594 b = 1.934082 mid = 1.933838 fmid = -0.000111 ea = 0.012625
% a = 1.933594 b = 1.933838 mid = 1.933716 fmid = 0.000050 ea = 0.006313

% %% [markdown]
% ## Regula Falsi Error

% %%
% Input Section
a = 1
b = 2
e = 0.001;

f = @(x) sin(x) - (x/2)^2;
fa = f(a)
fb = f(b)
% Finding Functional Value
fa = f(a);
fb = f(b);
er = abs(a-b)/a*100;
% Implementing Bisection Method
if fa*fb > 0 
    disp('Given initial values do not bracket the root.');
else
    c = a - (a-b) * fa/(fa-fb);
    fc = f(c);
    printf('\na\t\tb\t\tc\t\tf(x)\t\ter\n');
    while abs(er)>e
        printf('%f\t%f\t%f\t%d\t%d\n',a,b,c,f(c),er);
        if fa*fc< 0
            er = abs((b-c)/c)*100;
            b =c;
            fb = f(b);
        else
            er = abs((a-c)/c)*100;
            a = c;
            fa = f(a);
        end
        c = a - (a-b) * fa/(fa-fb);
        fc = f(c);
    end
    printf('%f\t%f\t%f\t%d\t%f\n',a,b,c,f(c),er);
    fprintf('\nRoot is: %f\n', c);
end
% Out:
% a =  1
% b =  2
% fa =  0.59147
% fb = -0.090703
%
% a		b		c		f(x)		er
% 1.000000	2.000000	1.867039	0.0849816	100
% 1.867039	2.000000	1.931355	0.00316741	46.4393
% 1.931355	2.000000	1.933671	0.000109618	3.33008
% 1.933671	2.000000	1.933751	3.78371e-06	0.119786
% 1.933751	2.000000	1.933754	1.30592e-07	0.00414038
% 1.933754	2.000000	1.933754	4.50725e-09	0.000143
%
% Root is: 1.933754

% %% [markdown]
% ## Fixed Point Error

% %%
f = @(x) 2*sqrt(sin(x));
a = 1;
b = 2;
e = 0.01;
ea = 100;
while (ea>e)
    mid = f(a);
    ea = abs((mid-a)/mid)*100;
    printf("Xi = %f\t G(x) = %f\tea = %f\n",a,mid,ea)
    a = mid;
end
% Out:
% Xi = 1.000000	 G(x) = 1.834635	ea = 45.493232
% Xi = 1.834635	 G(x) = 1.965091	ea = 6.638720
% Xi = 1.965091	 G(x) = 1.921736	ea = 2.256044
% Xi = 1.921736	 G(x) = 1.938092	ea = 0.843901
% Xi = 1.938092	 G(x) = 1.932151	ea = 0.307470
% Xi = 1.932151	 G(x) = 1.934341	ea = 0.113212
% Xi = 1.934341	 G(x) = 1.933538	ea = 0.041529
% Xi = 1.933538	 G(x) = 1.933833	ea = 0.015255
% Xi = 1.933833	 G(x) = 1.933725	ea = 0.005601

% %% [markdown]
% ## Fixed Point Iteration

% %%
f = @(x) 2*sqrt(sin(x));
a = 1;
b = 2;
itr = 10;
ea = 100;
for i = 1:itr
    mid = f(a);
    ea = abs((mid-a)/mid)*100;
    printf("Xi = %f\t G(x) = %f\tea = %f\n",a,mid,ea)
    a = mid;
end
% Out:
% Xi = 1.000000	 G(x) = 1.834635	ea = 45.493232
% Xi = 1.834635	 G(x) = 1.965091	ea = 6.638720
% Xi = 1.965091	 G(x) = 1.921736	ea = 2.256044
% Xi = 1.921736	 G(x) = 1.938092	ea = 0.843901
% Xi = 1.938092	 G(x) = 1.932151	ea = 0.307470
% Xi = 1.932151	 G(x) = 1.934341	ea = 0.113212
% Xi = 1.934341	 G(x) = 1.933538	ea = 0.041529
% Xi = 1.933538	 G(x) = 1.933833	ea = 0.015255
% Xi = 1.933833	 G(x) = 1.933725	ea = 0.005601
% Xi = 1.933725	 G(x) = 1.933764	ea = 0.002057

% %% [markdown]
% ## Newton Raphson Err

% %%
f = @(x) x^3 - 7*x^2 + 16*x - 12;
g = @(x) 3*x^2 -14*x +16;
e = 0.001;
ea = 100;
a = 0.5;
i = 0;
while(ea>e)
    i++;
    a1 = a - f(a)/g(a);
    ea = abs((a1-a)/a1)*100;
    printf("itr = %f\tXi = %f\tf(x) = %f   f'(x) = %f\tX(i+1) = %f\tea = %f\n",i,a,f(a), g(a),a1,ea);
    a = a1;
end
x = 1:20;
y = [];
for itr = x
    y = [y,f(itr)];
end
plot(x,y,'+')
% Out:
% itr = 1.000000	Xi = 0.500000	f(x) = -5.625000   f'(x) = 9.750000	X(i+1) = 1.076923	ea = 53.571429
% itr = 2.000000	Xi = 1.076923	f(x) = -1.638598   f'(x) = 4.402367	X(i+1) = 1.449132	ea = 25.684932
% itr = 3.000000	Xi = 1.449132	f(x) = -0.470620   f'(x) = 2.012105	X(i+1) = 1.683026	ea = 13.897263
% itr = 4.000000	Xi = 1.683026	f(x) = -0.132320   f'(x) = 0.935365	X(i+1) = 1.824489	ea = 7.753570
% itr = 5.000000	Xi = 1.824489	f(x) = -0.036211   f'(x) = 0.443434	X(i+1) = 1.906148	ea = 4.283996
% itr = 6.000000	Xi = 1.906148	f(x) = -0.009635   f'(x) = 0.214127	X(i+1) = 1.951144	ea = 2.306108
% itr = 7.000000	Xi = 1.951144	f(x) = -0.002504   f'(x) = 0.104873	X(i+1) = 1.975016	ea = 1.208701
% itr = 8.000000	Xi = 1.975016	f(x) = -0.000640   f'(x) = 0.051841	X(i+1) = 1.987358	ea = 0.621005
% itr = 9.000000	Xi = 1.987358	f(x) = -0.000162   f'(x) = 0.025764	X(i+1) = 1.993640	ea = 0.315102
% itr = 10.000000	Xi = 1.993640	f(x) = -0.000041   f'(x) = 0.012842	X(i+1) = 1.996810	ea = 0.158763
% itr = 11.000000	Xi = 1.996810	f(x) = -0.000010   f'(x) = 0.006411	X(i+1) = 1.998402	ea = 0.079693
% itr = 12.000000	Xi = 1.998402	f(x) = -0.000003   f'(x) = 0.003203	X(i+1) = 1.999201	ea = 0.039925
% itr = 13.000000	Xi = 1.999201	f(x) = -0.000001   f'(x) = 0.001601	X(i+1) = 1.999600	ea = 0.019983
% itr = 14.000000	Xi = 1.999600	f(x) = -0.000000   f'(x) = 0.000800	X(i+1) = 1.999800	ea = 0.009996
% itr = 15.000000	Xi = 1.999800	f(x) = -0.000000   f'(x) = 0.000400	X(i+1) = 1.999900	ea = 0.004999
% itr = 16.000000	Xi = 1.999900	f(x) = -0.000000   f'(x) = 0.000200	X(i+1) = 1.999950	ea = 0.002500
% itr = 17.000000	Xi = 1.999950	f(x) = -0.000000   f'(x) = 0.000100	X(i+1) = 1.999975	ea = 0.001250
% itr = 18.000000	Xi = 1.999975	f(x) = -0.000000   f'(x) = 0.000050	X(i+1) = 1.999987	ea = 0.000625

% %% [markdown]
% ## Newton Raphson Iteration

% %%
f = @(x) x^3 - 7*x^2 + 16*x - 12;
g = @(x) 3*x^2 -14*x +16;
e = 0.09;
er = 100;
a = 0.5;
itr = 5;
i = 0;
while(i<=itr)
    a1 = a - f(a)/g(a);
    er = abs((a1-a)/a1)*100;
    printf("itr = %d\t Xi = %f\tf(x) = %f   f'(x) = %f\tX(i+1) = %f\ter = %f\n",i,a,f(a), g(a),a1,er);
    a = a1;
    i++;
end
% Out:
% itr = 0	 Xi = 0.500000	f(x) = -5.625000   f'(x) = 9.750000	X(i+1) = 1.076923	er = 53.571429
% itr = 1	 Xi = 1.076923	f(x) = -1.638598   f'(x) = 4.402367	X(i+1) = 1.449132	er = 25.684932
% itr = 2	 Xi = 1.449132	f(x) = -0.470620   f'(x) = 2.012105	X(i+1) = 1.683026	er = 13.897263
% itr = 3	 Xi = 1.683026	f(x) = -0.132320   f'(x) = 0.935365	X(i+1) = 1.824489	er = 7.753570
% itr = 4	 Xi = 1.824489	f(x) = -0.036211   f'(x) = 0.443434	X(i+1) = 1.906148	er = 4.283996
% itr = 5	 Xi = 1.906148	f(x) = -0.009635   f'(x) = 0.214127	X(i+1) = 1.951144	er = 2.306108

% %% [markdown]
% ## First Modification

% %%
m = 2;
f = @(x) x^3 - 7*x^2 + 16*x - 12;
g = @(x) 3*x^2 -14*x +16;
e = 0.001;
er = 100;
a = 1;
i = 0;
while(er>e)
    a1 = a - m*(f(a)/g(a));
    er = abs((a1-a)/a1)*100;
    printf("itr = %f\tXi = %f\tf(x) = %f   f'(x) = %f  X(i+1) = %f  er = %f\n",i,a,f(a), g(a),a1,er);
    a = a1;
    i++;
end
% Out:
% itr = 0.000000	Xi = 1.000000	f(x) = -2.000000   f'(x) = 5.000000  X(i+1) = 1.800000  er = 44.444444
% itr = 1.000000	Xi = 1.800000	f(x) = -0.048000   f'(x) = 0.520000  X(i+1) = 1.984615  er = 9.302326
% itr = 2.000000	Xi = 1.984615	f(x) = -0.000240   f'(x) = 0.031479  X(i+1) = 1.999884  er = 0.763491
% itr = 3.000000	Xi = 1.999884	f(x) = -0.000000   f'(x) = 0.000231  X(i+1) = 2.000000  er = 0.005783
% itr = 4.000000	Xi = 2.000000	f(x) = 0.000000   f'(x) = 0.000000  X(i+1) = 2.000000  er = 0.000000

% %% [markdown]
% ## Second Modification

% %%
m = 2;
f = @(x) x^3 - 7*x^2 + 16*x - 12;
g = @(x) 3*x^2 -14*x +16;
h = @(x) 6*x -14;
e = 0.001;
er = 100;
a = 1;
i = 0;
while(er>e)
    a1 = a - (f(a)*g(a))/((g(a)^2) -f(a)*h(a)) ;
    er = abs((a1-a)/a1)*100;
    printf("itr = %d\t Xi = %f\tf(x) = %f  f'(x) = %f   f''(x) = %f  X(i+1) = %f  er = %f\n",i,a,f(a), g(a),h(a),a1,er);
    a = a1;
    i++;
end
% Out:
% itr = 0	 Xi = 1.000000	f(x) = -2.000000  f'(x) = 5.000000   f''(x) = -8.000000  X(i+1) = 2.111111  er = 52.631579
% itr = 1	 Xi = 2.111111	f(x) = -0.010974  f'(x) = -0.185185   f''(x) = -1.333333  X(i+1) = 2.007752  er = 5.148005
% itr = 2	 Xi = 2.007752	f(x) = -0.000060  f'(x) = -0.015324   f''(x) = -1.953488  X(i+1) = 2.000031  er = 0.386065
% itr = 3	 Xi = 2.000031	f(x) = -0.000000  f'(x) = -0.000061   f''(x) = -1.999817  X(i+1) = 2.000000  er = 0.001526
% itr = 4	 Xi = 2.000000	f(x) = 0.000000  f'(x) = -0.000000   f''(x) = -2.000000  X(i+1) = 2.000000  er = 0.000000

% %% [markdown]
% ## Secant Method Error

% %%
f = @(x) x^4*sin(x)-exp(x);
a = 1, fa = f(a)
b = 2 , fb = f(b)
e = 0.01;
err = 100;
i = 1;
while(e<err)
    c = b - f(b)*(b-a)/(f(b)-f(a));
    err = abs((c-b)/c)*100;
    printf("itr = %d\t  X = %d\tf(x) = %d \t\t er = %d\n",i,c,f(c),err);
    a = b;
    b = c;
    i++;
end
% Out:
% a =  1
% fa = -1.8768
% b =  2
% fb =  7.1597
% itr = 1	  X = 1.20769	f(x) = -1.35717 		 er = 65.6051
% itr = 2	  X = 1.33395	f(x) = -0.718076 		 er = 9.46479
% itr = 3	  X = 1.4758	f(x) = 0.34774 		 er = 9.61221
% itr = 4	  X = 1.42952	f(x) = -0.0422847 		 er = 3.23768
% itr = 5	  X = 1.43454	f(x) = -0.00200004 		 er = 0.349786
% itr = 6	  X = 1.43479	f(x) = 1.26446e-05 		 er = 0.0173631
% itr = 7	  X = 1.43479	f(x) = -3.73533e-09 		 er = 0.000109083

% %% [markdown]
% ## Muller Method

% %%
f = @(x) x^3+x^2+4*x-2;
first_dd = @(y,z) (f(z)-f(y))/(z-y);
second_dd = @(x,y,z) (first_dd(y,z)-first_dd(x,y))/(z-x);

x = 0;
y = 1;
z = 2;
err=100;
e = 0.01;
while(err>e)
    fx = f(x);
    fy = f(y);
    fz = f(z);
    fxy = first_dd(x,y);
    fyz = first_dd(y,z);
    fxz = first_dd(x,z);
    a = second_dd(x,y,z);
    b = fxz + a*(z-x);
    c = fz;
    D = sqrt(b^2 - 4*a*c);
    % Problem why - not +
    delta = -(2*c)/(b+D);
    newX = z + delta;
    err = abs((newX-z)/newX)*100;
    printf("x0=%d\t x2=%d\t x3=%d\t f0=%d\t f1=%d\t f2=%d\t f[x2,x1]=%d\t  f[x1,x0]=%d\t f[x2,x1,x0]=%d\t a=%d\t b=%d\t c=%d\t det=%d\n(x3-x2) = %d\t x3 = %d\t err=%d\n",x,y,z,fx,fy,fz,fxy,fyz,a,a,b,c,D,delta,newX,err)
    printf("___________________________________________________\n")
    x = y;
    y = z;
    z = newX;
end
% Out:
% x0=0	 x2=1	 x3=2	 f0=-2	 f1=4	 f2=18	 f[x2,x1]=6	  f[x1,x0]=14	 f[x2,x1,x0]=4	 a=4	 b=18	 c=18	 det=6
% (x3-x2) = -1.5	 x3 = 0.5	 err=300
% ___________________________________________________
% x0=1	 x2=2	 x3=0.5	 f0=4	 f1=18	 f2=0.375	 f[x2,x1]=14	  f[x1,x0]=11.75	 f[x2,x1,x0]=4.5	 a=4.5	 b=5	 c=0.375	 det=4.272
% (x3-x2) = -0.0808887	 x3 = 0.419111	 err=19.3
% ___________________________________________________
% x0=2	 x2=0.5	 x3=0.419111	 f0=18	 f1=0.375	 f2=-0.0742817	 f[x2,x1]=11.75	  f[x1,x0]=5.55432	 f[x2,x1,x0]=3.91911	 a=3.91911	 b=5.23731	 c=-0.0742817	 det=5.34732
% (x3-x2) = 0.0140358	 x3 = 0.433147	 err=3.24042
% ___________________________________________________
% x0=0.5	 x2=0.419111	 x3=0.433147	 f0=0.375	 f1=-0.0742817	 f2=0.00147023	 f[x2,x1]=5.55432	  f[x1,x0]=5.39707	 f[x2,x1,x0]=2.35226	 a=2.35226	 b=5.43008	 c=0.00147023	 det=5.42881
% (x3-x2) = -0.000270788	 x3 = 0.432876	 err=0.0625555
% ___________________________________________________
% x0=0.419111	 x2=0.433147	 x3=0.432876	 f0=-0.0742817	 f1=0.00147023	 f2=2.50196e-07	 f[x2,x1]=5.39707	  f[x1,x0]=5.42852	 f[x2,x1,x0]=2.28513	 a=2.28513	 b=5.4279	 c=2.50196e-07	 det=5.4279
% (x3-x2) = -4.60945e-08	 x3 = 0.432876	 err=1.06484e-05
% ___________________________________________________

% %% [markdown]
% ## Doolittle

% %%
function [L,U] = getLU(A)
    % Number of Rows or Columns of Matrix A
    n = size(A)(1);
 
    % L and U are Lower and Upper Triangle Matrix respectively.
    U = zeros(n,n);
    L = zeros(n,n);
 
    % LU decomposition using Gauss Elimination
    for i = 1:n
        %upper tiangular 
        for j = i:n
          sum = 0;
          for k = 1:i-1
            sum+= (L(i,k) * U(k,j));
           end
            U(i,j) = A(i,j) - sum;
            printf("U(%d, %d) = %d - %d = %d\n",i,j,A(i,j),sum,U(i,j))
        end
       %Lower Tringular
       for j = i:n
          if i == j
            L(i,i) = 1;
          else
            sum = 0;
            for k = 1:i-1
              sum+= (L(j,k) * U(k,i));
            end
              L(j,i) = (A(j,i) - sum)/U(i,i);
              printf("L(%d, %d) = (%d - %d)/(%d) = %d\n",j,i,A(j,i), sum,U(i,i),L(j,i))
          end
       end
       printf("\n--------------\n")
    end
end
[L,U] = getLU([5,1,0;1,5,1;0,1,5]);
L,U
% function x = solve(A,M)
%     [L,U] = getLU(A);
%     n = size(A)(1);
%     % Backward Substitution L * d = M  where d = UX
%     d = zeros(n,1);
%     for i = 1:n
%         sigma = M(i,1);
%         for j = 1:i-1
%             sigma -= L(i,j)*d(j,1) ;
%         end
%         d(i,1) = sigma/L(i,i) ;
%     end
    
%     L, d
%     % Backward Substitution d = U * X
%     x = zeros(n,1);
%     for i = n:-1:1
%         sigma = d(i,1);
%         for j = n:-1:i+1
%             sigma -= U(i,j)*x(j,1) ;
%         end
%     x(i,1) = sigma/U(i,i) ;
%     end
%     U
% end
% A = [5 1 0; 1 5 1; 0 1 5];
% b = [7 ;14; 17];
% solve(A,b)
% Out:
% U(1, 1) = 5 - 0 = 5
% U(1, 2) = 1 - 0 = 1
% U(1, 3) = 0 - 0 = 0
% L(2, 1) = (1 - 0)/(5) = 0.2
% L(3, 1) = (0 - 0)/(5) = 0
%
% --------------
% U(2, 2) = 5 - 0.2 = 4.8
% U(2, 3) = 1 - 0 = 1
% L(3, 2) = (1 - 0)/(4.8) = 0.208333
%
% --------------
% U(3, 3) = 5 - 0.208333 = 4.79167
%
% --------------
% L =
%
%    1.00000   0.00000   0.00000
%    0.20000   1.00000   0.00000
%    0.00000   0.20833   1.00000
%
% U =
%
%    5.00000   1.00000   0.00000
%    0.00000   4.80000   1.00000
%    0.00000   0.00000   4.79167

% %% [markdown]
% ## Crout

% %%
function [L,U] = getLU(A)
    % Number of Rows or Columns of Matrix A
    n = size(A)(1);
 
    % L and U are Lower and Upper Triangle Matrix respectively.
    U = zeros(n,n);
    L = zeros(n,n);
 
    % LU decomposition using Gauss Elimination
    for i = 1:n
        %lower tiangular 
        for j = i:n
          sum = 0;
          for k = 1:j-1
            sum+= (L(j,k) * U(k,i));
           end
            L(j,i) = A(j,i) - sum;
            printf("L(%d, %d) = %d - %d = %d\n",j,i,A(j,i),sum,L(j,i))
        end
       %upper Tringular
       for j = i:n
          if i == j
            U(i,i) = 1;
          else
            sum = 0;
            for k = 1:i-1
              sum+= (L(i,k) * U(k,j));
            end
              U(i,j) = (A(i,j) - sum)/L(i,i);
              printf("U(%d, %d) = (%d - %d)/(%d) = %d\n",i,j,A(i,j), sum,L(i,i),U(i,j))
          end
       end
       printf("\n------------\n");
    end
end
[L,U] = getLU([2,-6,-1;-8,1,-2;-3,-1,7])

% function x = solve(A,M)
%     [L,U] = getLU(A);
%     n = size(A)(1);
%     % Backward Substitution L * d = M  where d = UX
%     d = zeros(n,1);
%     for i = 1:n
%         sigma = M(i,1);
%         for j = 1:i-1
%             sigma -= L(i,j)*d(j,1) ;
%         end
%         d(i,1) = sigma/L(i,i) ;
%     end
    
%     L, d
%     % Backward Substitution d = U * X
%     x = zeros(n,1);
%     for i = n:-1:1
%         sigma = d(i,1);
%         for j = n:-1:i+1
%             sigma -= U(i,j)*x(j,1) ;
%         end
%     x(i,1) = sigma/U(i,i) ;
%     end
%     U
% end
% A = [5 1 0; 1 5 1; 0 1 5];
% b = [7 ;14; 17];
% solve(A,b)
% Out:
% L(1, 1) = 2 - 0 = 2
% L(2, 1) = -8 - 0 = -8
% L(3, 1) = -3 - 0 = -3
% U(1, 2) = (-6 - 0)/(2) = -3
% U(1, 3) = (-1 - 0)/(2) = -0.5
%
% ------------
% L(2, 2) = 1 - 24 = -23
% L(3, 2) = -1 - 9 = -10
% U(2, 3) = (-2 - 4)/(-23) = 0.26087
%
% ------------
% L(3, 3) = 7 - -1.1087 = 8.1087
%
% ------------
% L =
%
%     2.00000    0.00000    0.00000
%    -8.00000  -23.00000    0.00000
%    -3.00000  -10.00000    8.10870
%
% U =
%
%    1.00000  -3.00000  -0.50000
%    0.00000   1.00000   0.26087
%    0.00000   0.00000   1.00000

% %% [markdown]
% ## Cholesky

% %%
function [L,U] = getLU(A)
    % Number of Rows or Columns of Matrix A
    n = size(A)(1);
 
    % L and U are Lower and Upper Triangle Matrix respectively.
    U = zeros(n,n);
    L = zeros(n,n);
 
    % LU decomposition using Gauss Elimination
    for i = 1:n
        for j = i:n
            if i==j
                sum = 0;
                for k = 1:j-1
                    sum += L(j,k)^2;
                end
                L(i,i) = sqrt(A(i,i) - sum);
                printf("L(%d, %d) = sqrt(%d - %d) = %d\n",i,i,A(i,i), sum,L(i,i))
                
            else
                sum = 0;
                for k = 1:j-1
                    sum += L(j,k)*L(i,k);
                end
                L(j,i) = (A(j,i) - sum)/(L(i,i));
                printf("L(%d, %d) = (%d - %d)/(%d) = %d\n",j,i,A(j,i), sum,L(i,i), L(j,i))
            end
        end
       printf("\n------------\n");
    end
    U = L';
end
[L,U] = getLU([4,2,14;2,17,-5;14,-5,83]);

function x = solve(A,M)
    [L,U] = getLU(A);
    n = size(A)(1);
    % Backward Substitution L * d = M  where d = UX
    d = zeros(n,1);
    for i = 1:n
        sigma = M(i,1);
        for j = 1:i-1
            sigma -= L(i,j)*d(j,1) ;
        end
        d(i,1) = sigma/L(i,i) ;
    end
    
    L, d
    % Backward Substitution d = U * X
    x = zeros(n,1);
    for i = n:-1:1
        sigma = d(i,1);
        for j = n:-1:i+1
            sigma -= U(i,j)*x(j,1) ;
        end
    x(i,1) = sigma/U(i,i) ;
    end
    U
end
A = [5 1 0; 1 5 1; 0 1 5];
b = [7 ;14; 17];
solve(A,b)
% Out:
% L(1, 1) = sqrt(4 - 0) = 2
% L(2, 1) = (2 - 0)/(2) = 1
% L(3, 1) = (14 - 0)/(2) = 7
%
% ------------
% L(2, 2) = sqrt(17 - 1) = 4
% L(3, 2) = (-5 - 7)/(4) = -3
%
% ------------
% L(3, 3) = sqrt(83 - 58) = 5
%
% ------------
% L(1, 1) = sqrt(5 - 0) = 2.23607
% L(2, 1) = (1 - 0)/(2.23607) = 0.447214
% L(3, 1) = (0 - 0)/(2.23607) = 0
%
% ------------
% L(2, 2) = sqrt(5 - 0.2) = 2.19089
% L(3, 2) = (1 - 0)/(2.19089) = 0.456435
%
% ------------
% L(3, 3) = sqrt(5 - 0.208333) = 2.18899
%
% ------------
% L =
%
%    2.23607   0.00000   0.00000
%    0.44721   2.19089   0.00000
%    0.00000   0.45644   2.18899
%
% d =
%
%    3.1305
%    5.7511
%    6.5670
%
% U =
%
%    2.23607   0.44721   0.00000
%    0.00000   2.19089   0.45644
%    0.00000   0.00000   2.18899
%
% ans =
%
%    1.0000
%    2.0000
%    3.0000

% %% [markdown]
% ## Solve

% %% [markdown]
% ### Thomson

% %%
function [L,U] = getLU(A,b)
    % Number of Rows or Columns of Matrix A
    n = size(A)(1);
    l = zeros(1,n);
    d = zeros(1,n);
    u = zeros(1,n)
    alpha = zeros(1,n);
    beta = zeros(1,n);
    
    l(1,1) = 0, u(1,n) = 0
    
    cnt = 1
    for i = 1:n
        for j = 1:n
            
            if i==j
            d(1,cnt) = A(i,j);
            elif i+1==j
            
            printf("L(%d, %d) = sqrt(%d - %d) = %d\n",i,i,A(i,i), sum,L(i,i))
                
            else
                sum = 0;
                for k = 1:j-1
                    sum += L(j,k)*L(i,k);
                end
                L(j,i) = (A(j,i) - sum)/(L(i,i));
                printf("L(%d, %d) = (%d - %d)/(%d) = %d\n",j,i,A(j,i), sum,L(i,i), L(j,i))
            end
        end
       printf("\n------------\n");
    end
    U = L';
end

% %%
## -*- texinfo -*-
## @deftypefn  {Function File} {} input ()
## @deftypefnx {Function File} {} input (@var{PROMPT})
## @deftypefnx {Function File} {} input (@var{PROMPT}, 's')
## Print PROMPT and wait for user input
##
## @end deftypefn

function ANS = input (varargin)
    % let the builtin handle the nargin error
    if (nargin == 0)
      builtin('input')
    end
    varargin{1} = sprintf('%s__stdin_prompt>', varargin{1});
    ANS = builtin('input', varargin{:});
endfunction

% %%
# prutor-lang:octave

yes_no = input("Is the equation is a polynomial(Y/N):\n",'s');

function f = vect2func(a)
    n = size(a)(2);
    func = "0";
    for i= 1:n
        func = [func," + (",num2str(a(1,i)),"*x","^",num2str(i-1),")"];
    end
    f = inline(func,'x');
end

function [x1,x2] = getRoot(r,s)
    x1 = (r + sqrt(r^2 + 4*s))/(2);
    x2 = (r - sqrt(r^2 + 4*s))/(2);
end


function [r,s,Er1,Er2,B,stopCondition,Itr,f] = bairItr(a,r,s,c1,c2,c3)    
    er1 = 100; 
    er2 = 100;
    n = size(a)(2);
    itr = 0;
    stopConditon = -1;
    f = vect2func(a);
    B = [];
    Er1 = []; Er2 = []; Itr = [];
    
    while(true)
        b = zeros(1,n);
        c = zeros(1,n);
        
        b(1,n) = a(1,n);
        c(1,n) = b(1,n);
        b(1,n-1) = a(1,n-1) + r*b(1,n);
        c(1,n-1) = b(1,n-1) + r*c(1,n);
        for i = n-2:-1:1
            b(1,i) = a(1,i) + r*b(1,i+1) + s*b(1,i+2);
          c(1,i) = b(1,i) + r*c(1,i+1) + s*c(1,i+2);
        end
    
        C = [c(1,2), c(1,3) ; c(1,3), c(1,4)];
        InvC = inv(C);
        B = [-b(i,1) ; -b(i,2)];
        temp = InvC * B;
        delr = temp(1,1);
        dels = temp(2,1);
        r += delr;
        s += dels;
        
        er1 = abs((delr)/r)*100;
        er2 = abs((dels)/s)*100;
        Er1 = [Er1, er1];
        Er2 = [Er2, er2];
        [x1,x2] = getRoot(r,s);
        
        B = b;
        itr = itr+1;
        Itr = [Itr, itr];
        c3;
        if er1<c1 && er2<c1
            stopCondition = 1;
            break;
        end
        if abs(f(x1)) < c2 && abs(f(x2))< c2
            stopCondition = 2;
            break;
        end
        if itr >= c3 
            stopCondition = 3;
            break;
        end
    end 
end


        
if(yes_no == "Y")
    a = input("Please enter the polynomial coefficients (a0,…an):\n");
    r = input("r:");
    s = input("s:");
    disp("Now enter the stopping criterias:\n");
    c1 = input("Convergence criterion for relative approximate errors in successive iterations.\n");
    c2 = input("Convergence criteria for the function value, i.e., how close f(x) is to zero:\n");
    c3 = input("Maximum iteration number:\n");
    X = [];
    while(size(a)(2)>2)
        [r,s,Er1,Er2,B,stopCondition,Itr,f] = bairItr(a,r,s,c1,c2,c3);
        [x1,x2] = getRoot(r,s);
        X = [X,x1,x2];
        a = B(1,3:size(B)(2));
    end
    
    if(size(a)(2)==2)
        X = [X, a(1,1)/a(1,2)];
    end
    xx = -100:1:100 ;
    yy = [];
    for i = xx
        yy = [yy, f(i)];
    end
    figure,plot(xx,yy)
    xlabel("X - axis");
    ylabel("Y - axis");
end
% Out:
% Is the equation is a polynomial(Y/N):

% %%
function [L,U] = getLU(A)
    % Number of Rows or Columns of Matrix A
    n = size(A)(1);
    
    % L and U are Lower and Upper Triangle Matrix respectively.
    U = A;
    L = eye(n,n);
    
    % LU decomposition using Gauss Elimination
    for j = 1:n
        %printf("Nice");
        for i2 = j+1:n
            if (U(j,j) == 0)
                printf("Bad");
                break;
            end
            
            coef = U(i2,j)/U(j,j);
            L(i2,j) = coef;
            
            for j2 = 1:n
                U(i2,j2) -= U(j,j2)*coef; 
            end
        end
    end
end

% %% [markdown]
% ## Max Eigen Value and Normalised Eigen Vector

% %%
A = [2 2; 1 3]
X = [1 ; 0]

etol = 0.1;
ea = 100;

function [lambda, Xnew] = getEigen(A,X)
    %Step - 1  => y
    y = A*X
    %Step - 2 => lambda - Eigen Value
    lambda = (abs(min(y))>max(y))*min(y) + (abs(min(y))<=max(y))*max(y)
    %Step -3 => Eigen Vector
    Xnew = y/lambda
end
lambda = 0;
itr = 0;
while(ea > etol) 
    itr++;
    printf("\nIteration %d _______\n",itr);
    [lambdaNew, X] = getEigen(A,X);
    ea = abs((lambdaNew - lambda)/(lambdaNew))*100
    lambda = lambdaNew;
end
printf("\n\n____Final Solution _________\n\n"); 
lambdaMax = lambda
Umax = X
Unormalized = X/norm(X)
% Out:
% A =
%
%    2   2
%    1   3
%
% X =
%
%    1
%    0
%
%
% Iteration 1 _______
% y =
%
%    2
%    1
%
% lambda =  2
% Xnew =
%
%    1.00000
%    0.50000
%
% ea =  100
%
% Iteration 2 _______
% y =
%
%    3.0000
%    2.5000
%
% lambda =  3
% Xnew =
%
%    1.00000
%    0.83333
%
% ea =  33.333
%
% Iteration 3 _______
% y =
%
%    3.6667
%    3.5000
%
% lambda =  3.6667
% Xnew =
%
%    1.00000
%    0.95455
%
% ea =  18.182
%
% Iteration 4 _______
% y =
%
%    3.9091
%    3.8636
%
% lambda =  3.9091
% Xnew =
%
%    1.00000
%    0.98837
%
% ea =  6.2016
%
% Iteration 5 _______
% y =
%
%    3.9767
%    3.9651
%
% lambda =  3.9767
% Xnew =
%
%    1.00000
%    0.99708
%
% ea =  1.7012
%
% Iteration 6 _______
% y =
%
%    3.9942
%    3.9912
%
% lambda =  3.9942
% Xnew =
%
%    1.00000
%    0.99927
%
% ea =  0.43583
%
% Iteration 7 _______
% y =
%
%    3.9985
%    3.9978
%
% lambda =  3.9985
% Xnew =
%
%    1.00000
%    0.99982
%
% ea =  0.10964
%
% Iteration 8 _______
% y =
%
%    3.9996
%    3.9995
%
% lambda =  3.9996
% Xnew =
%
%    1.00000
%    0.99995
%
% ea =  0.027452
%
%
% ____Final Solution _________
%
% lambdaMax =  3.9996
% Umax =
%
%    1.00000
%    0.99995
%
% Unormalized =
%
%    0.70712
%    0.70709

% %% [markdown]
% ## Min Eigen Value and Normalised Eigen Vector

% %%
A = [-1.5 2; 1 -0.5];
A = inv(A)
X = [1 ; 0]

etol = 0.1;
ea = 100;

function [lambda, Xnew] = getEigen(A,X)
    %Step - 1  => y
    y = A*X
    %Step - 2 => lambda - Eigen Value
    lambda = (abs(min(y))>max(y))*min(y) + (abs(min(y))<=max(y))*max(y)
    %Step -3 => Eigen Vector
    Xnew = y/lambda
end
lambda = 0;
itr = 0;
while(ea > etol) 
    itr++;
    printf("\nIteration %d _______\n",itr);
    [lambdaNew, X] = getEigen(A,X);
    ea = abs((lambdaNew - lambda)/(lambdaNew))*100
    lambda = lambdaNew;
end
printf("\n\n____Final Solution _________\n\n"); 
lambdaMin = 1/lambda
Umin = X
Unormalized = X/norm(X)
% Out:
% A =
%
%    0.40000   1.60000
%    0.80000   1.20000
%
% X =
%
%    1
%    0
%
%
% Iteration 1 _______
% y =
%
%    0.40000
%    0.80000
%
% lambda =  0.80000
% Xnew =
%
%    0.50000
%    1.00000
%
% ea =  100
%
% Iteration 2 _______
% y =
%
%    1.8000
%    1.6000
%
% lambda =  1.8000
% Xnew =
%
%    1.00000
%    0.88889
%
% ea =  55.556
%
% Iteration 3 _______
% y =
%
%    1.8222
%    1.8667
%
% lambda =  1.8667
% Xnew =
%
%    0.97619
%    1.00000
%
% ea =  3.5714
%
% Iteration 4 _______
% y =
%
%    1.9905
%    1.9810
%
% lambda =  1.9905
% Xnew =
%
%    1.00000
%    0.99522
%
% ea =  6.2201
%
% Iteration 5 _______
% y =
%
%    1.9923
%    1.9943
%
% lambda =  1.9943
% Xnew =
%
%    0.99904
%    1.00000
%
% ea =  0.18965
%
% Iteration 6 _______
% y =
%
%    1.9996
%    1.9992
%
% lambda =  1.9996
% Xnew =
%
%    1.00000
%    0.99981
%
% ea =  0.26794
%
% Iteration 7 _______
% y =
%
%    1.9997
%    1.9998
%
% lambda =  1.9998
% Xnew =
%
%    0.99996
%    1.00000
%
% ea =  0.0076762
%
%
% ____Final Solution _________
%
% lambdaMin =  0.50006
% Umin =
%
%    0.99996
%    1.00000
%
% Unormalized =
%
%    0.70709
%    0.70712

% %% [markdown]
% ### Newton Raphson - 2 variables

% %%
u = @(x,y) x^2 - x + y - 0.75;
v = @(x,y) x^2 - 5*x*y - y;
dux = @(x,y) 2*x -1 ;
duy = @(x,y) 1;
dvx = @(x,y) -5*y + 2*x;
dvy = @(x,y) -5*x - 1;
D = @(x,y) dux(x,y)*dvy(x,y) - duy(x,y)*dvx(x,y);
x = zeros();
y = zeros();
x(1) = 1.2;
y(1) = 1.2;
tol = 0.1;
eax = zeros();
eay = zeros();
eax(1) = 100;
eay(1) = 100;
itr = 1;
maxItr = 10;
while(itr<maxItr && (max(eax(itr),eay(itr))>tol))
    printf("\n__________Iteration %d________\n",itr);
    U = u(x(itr),y(itr))
    V = v(x(itr),y(itr))
    Dux = dux(x(itr),y(itr))
    Duy = duy(x(itr),y(itr))
    Dvx = dvx(x(itr),y(itr))
    Dvy = dvy(x(itr),y(itr))
    d = D(x(itr),y(itr))
    x(itr+1) = x(itr) - (dvy(x(itr),y(itr))*u(x(itr),y(itr)) - duy(x(itr),y(itr))*v(x(itr),y(itr)))/D(x(itr),y(itr)) ;
    y(itr+1) = y(itr) - (-dvx(x(itr),y(itr))*u(x(itr),y(itr)) + dux(x(itr),y(itr))*v(x(itr),y(itr)))/D(x(itr),y(itr));
    eax(itr+1) = abs((x(itr+1)-x(itr))/x(itr+1))*100;
    eay(itr+1) = abs((y(itr+1)-y(itr))/y(itr+1))*100;
    X = x(itr+1)
    Y = y(itr+1)
    Ex = eax(itr+1)
    Ey = eay(itr+1)
    itr++;
end
% Out:
% __________Iteration 1________
% U =  0.69000
% V = -6.9600
% Dux =  1.4000
% Duy =  1
% Dvx = -3.6000
% Dvy = -7
% d = -6.2000
% X =  1.5435
% Y =  0.029032
% Ex =  22.257
% Ey =  4033.3
%
% __________Iteration 2________
% U =  0.11803
% V =  2.1294
% Dux =  2.0871
% Duy =  1
% Dvx =  2.9419
% Dvy = -8.7177
% d = -21.137
% X =  1.3941
% Y =  0.22287
% Ex =  10.718
% Ey =  86.974
%
% __________Iteration 3________
% U =  0.022328
% V =  0.16715
% Dux =  1.7882
% Duy =  1
% Dvx =  1.6739
% Dvy = -7.9706
% d = -15.927
% X =  1.3725
% Y =  0.23929
% Ex =  1.5788
% Ey =  6.8621
%
% __________Iteration 4________
% U =  0.00046952
% V =  0.0022485
% Dux =  1.7449
% Duy =  1
% Dvx =  1.5484
% Dvy = -7.8623
% d = -15.267
% X =  1.3721
% Y =  0.23950
% Ex =  0.028356
% Ey =  0.087417

% %% [markdown]
% ### Bairstow

% %%
%order = input('Enter the order of the polynomial (A Natural Number Please): ');
order = input('');
   % x = input('Enter polynomial coefficients like [ a0 a1 a2 ] : ');
   x = input('');
     % disp('Now you will be asked to enter two starting points <r> <s>.');
      %  r = input('Enter r : ');
       r = input('');
       % s = input('Enter s : ');
       s = input('');
       % disp('Now you will be asked to enter 3 stopping criteria.');
       % sta = input('Enter Convergence criterion for relative approximate errors in successive iterations : ');
        sta = input(' ');
       
       % stc = input('Enter Maximum iteration number (an integer) : ');
       stc = input('');
        % solve here
       % bairstow(order, x, r, s, sta, stb, stc);
     disp(x);

    itr = 0;
    bac_r = r;
    bac_s = s;
    c = 1:order+1;
    b = 1:order+1;
    rootcounter = 1;
    count=1;
    y2s = 1:1;
    y2r = 1:1;
    while order>2
        n = order+1;
        itr = itr + 1;
        b(n) = x(n);
        b(n-1) = x(n-1) + r*b(n);
        for i = 2:n-1
            b(n-i) = x(n-i) + r*b(n-i+1) + s*b(n-i+2);
        end
        c(n) = b(n);
        c(n-1) = b(n-1) + r*c(n);
        for i = 2:n-1
            c(n-i) = b(n-i) + r*c(n-i+1) + s*c(n-i+2);
        end
        m_c = [c(2) c(3); c(3) c(4)];
        m_ci = inv(m_c);
        m_b = [-b(1); -b(2)];
        d = m_ci*m_b;
        r = r + d(1);
        s = s + d(2);
        y2r(itr) = abs((d(1))/(r - d(1)))*100;
        y2s(itr) = abs((d(2))/(s - d(2)))*100;
        if abs((d(1))/(r - d(1)))*100<=sta || abs((d(2))/(s - d(2)))*100<=sta
           % rootcounter = solveroot(r, s, rootcounter);
                if (r*r + 4*s) < 0
        x = (r + sqrt(r*r + 4*s))/2;
        disp(['root ' num2str(count) ' : ' num2str(real(x)) ' + ' num2str(imag(x)) 'i']);
        x = (r - sqrt(r*r + 4*s))/2;
        disp(['root ' num2str(count+1) ' : ' num2str(real(x)) ' + ' num2str(imag(x)) 'i']);
        y = count + 2;
    elseif (r*r + 4*s) == 0
        x = (r/2);
        disp(['root ' num2str(count) ' : ' num2str(x)]);
        y = count + 1;
    else
        x = (r + sqrt(r*r + 4*s))/2;
        disp(['root ' num2str(count) ' : ' num2str(x)]);
        x = (r - sqrt(r*r + 4*s))/2;
        disp(['root ' num2str(count+1) ' : ' num2str(x)]);
        y = count + 2;
    end
            
            for i= 1:n-2
                x(i) = b(i+2);
            end
           
            order = order - 2;
            itr = 0;
            y2r = 1:1;
            y2s = 1:1;
            r = bac_r;
            s = bac_s;
        end
      
        if itr>stc
            disp('Stopped doe to criteria 3');
            break;
        end
    
    if order==1
        disp(['root ' num2str(rootcounter) ' : ' num2str(-x(1)/x(2))]);
    elseif order==2
        r = -x(2)/x(3);
        s = -x(1)/x(3);
        %solveroot(r, s, rootcounter);
         if (r*r + 4*s) < 0
        x = (r + sqrt(r*r + 4*s))/2;
        disp(['root ' num2str(rootcounter) ' : ' num2str(real(x)) ' + ' num2str(imag(x)) 'i']);
        x = (r - sqrt(r*r + 4*s))/2;
        disp(['root ' num2str(rootcounter+1) ' : ' num2str(real(x)) ' + ' num2str(imag(x)) 'i']);
        y = rootcounter + 2;
    elseif (r*r + 4*s) == 0
        x = (r/2);
        disp(['root ' num2str(rootcounter) ' : ' num2str(x)]);
        y = rootcounter + 1;
    else
        x = (r + sqrt(r*r + 4*s))/2;
        disp(['root ' num2str(rootcounter) ' : ' num2str(x)]);
        x = (r - sqrt(r*r + 4*s))/2;
        disp(['root ' num2str(rootcounter+1) ' : ' num2str(x)]);
        y = rootcounter + 2;
    end
    end
    end

% %% [markdown]
% ### Partial Pivoting

% %%
A = [1 2 3; 2 2 2; 3 3 3]
b = [1;2;3]

function [L,b] = doPivot(A,b)
    n = size(A)(1);
    for col = 1:n
        % Find max|a(i,col)|
        mxRow = col;
        mxVal = A(col,col);
        for i=col:n 
            if(mxVal<A(i,col))
                mxVal = A(i,col);
                mxRow = i;
            end
        end
        
        temp=A(col,:);
        A(col,:)=A(mxRow,:);
        A(mxRow,:)=temp
        tmp = b(col);
        b(col) = b(mxRow);
        b(mxRow) = tmp;
        nor = A(col,col);
        if nor!=0
            for j = col:n
                A(col,j)/=nor;
            end
            b(col)/=nor;
        end
        for i=col+1:n
            fact = A(i,col);
            for j = 1:n
                A(i,j) -= fact*A(col,j);
            end
            b(i)-=fact*b(col);
        end
    end
    L = A;
end

[L,b] = doPivot(A,b)

% %% [markdown]
% ### Gauss Seidel

% %%
mat=[2, 0, -1, 1, 1;
1, 2, 0, 0, 1.5;
0, -1, 2, 0, 1.5;
0, 2, -1, 1, 2];
n = size(mat)(1);
m  = size(mat)(2);
x = zeros (m-1 ,1);
x1 = zeros (m-1 ,1);
e = zeros (m-1 ,1);
itr = 0;
while 1
    itr++
    x1
    
  for i = 1:n
    sum = 0;
    for j = 1:m-1
      if (j == i)
        continue;
        endif
      sum = sum + mat(i,j) * x1(j ,1); 
    endfor
    x1(i) = (mat(i,m) - sum)/mat(i,i);
    e(i) = abs((x1(i)-x(i))/x1(i))*100;
  endfor
  x=x1;
  norm(e,Inf)
  printf("\n");
  if norm(e,Inf) <= .01
    break;
  endif
endwhile

% %% [markdown]
% ### Jacobi

% %%
mat=[2, 0, -1, 1, 1;
1, 2, 0, 0, 1.5;
0, -1, 2, 0, 1.5;
0, 2, -1, 1, 2];
n = size(mat)(1);
m  = size(mat)(2);
x = zeros(n,1);
x1 = zeros(n,1);
e = zeros();
while 1
  for i = 1:n
    sum = 0;
    for j = 1:n
      if (j == i)
        continue;
      endif
      sum = sum + mat(i,j) * x(j); 
    endfor
    x1(i) = (mat(i,m) - sum)/mat(i,i)
    e(i) = abs((x1(i)-x(i))/x1(i));
  endfor
  x = x1;
  printf("\n");
  if norm(e,Inf) <= .001
    break;
  endif
endwhile
% Out:
% x1 =
%
%    0.50000
%    0.00000
%    0.00000
%    0.00000
%
% x1 =
%
%    0.50000
%    0.75000
%    0.00000
%    0.00000
%
% x1 =
%
%    0.50000
%    0.75000
%    0.75000
%    0.00000
%
% x1 =
%
%    0.50000
function [q,r] = QRdecompos(a)
    n = size(a)(2);
    q = zeros(n,n);
    r = zeros(n,n);
    q(:,1) = a(:,1)/norm(a(:,1),2);
    for k = 1:n-1
        sigma = 0;
        for i = 1:k
            sigma += ((a(:,k+1)')*q(:,i))*q(:,i) ;
        end
        z = a(:,k+1) - sigma;
        q(:,k+1) = z/norm(z,2);
    end
    for i = 1:n
        for j = i:n
            r(i,j) = (q(:,i)')*a(:,j);
        end
    end
end
Q = []; R = [];
for steps = 1:1
    [Q,R] = QRdecompos(a);
    a = R*Q;
end
Q , R, (Q*(Q')), Q*R
% Out:
% a =
%
%    3   4   1
%    3   5   1
%    2   2   1
%
% Q =
%
%    0.63960  -0.19795  -0.74278
%    0.63960   0.67304   0.37139
%    0.42640  -0.71263   0.55709
%
% R =
%
%    4.69042   6.60922   1.70561
%    0.00000   1.14812  -0.23754
%    0.00000   0.00000   0.18570
%
% ans =
%
%    1.0000e+00  -1.0418e-15   9.1371e-16
%   -1.0418e-15   1.0000e+00  -3.4583e-16
%    9.1371e-16  -3.4583e-16   1.0000e+00
%
% ans =
%
%    3.00000   4.00000   1.00000
%    3.00000   5.00000   1.00000
%    2.00000   2.00000   1.00000

% %% [markdown]
% ### Regression

% %%
% Linear Regression
x = [0.1 0.2 0.5 1.3 4.2 9.5];
y = [2.85 4 6 10 15 20];

%Transformation
x = arrayfun(@(x) 1/sqrt(x), x);
y = arrayfun(@(y) 1/y , y);

n = size(y)(2);
sigmaX = sum(x)
sigmaY = sum(y)
sigmaXX = (x)*(x')
sigmaXY = (x)*(y')
A = [n sigmaX; sigmaX sigmaXX]
B = [sigmaY; sigmaXY]
a = (inv(A))*B
f = @(x) a(1) + a(2)*x;

F = zeros();
xi = zeros();
for i = 0:10
    F(i+1) = f(i);
    xi(i+1) = i;
end
ym = sigmaY/n

aa = 1/a(2)
bb = a(1)/a(2)

s0 = (y-ym)*((y-ym)')
yhat = zeros();
j = 1
for i = x
    yhat(j++) = f(i);
end
sr = (y-yhat)*((y-yhat)')
r2 = 1 - sr/s0
% Out:
% sigmaX =  8.5020
% sigmaY =  0.98421
% sigmaXX =  18.113
% sigmaXY =  2.0407
% A =
%
%     6.0000    8.5020
%     8.5020   18.1126
%
% B =
%
%    0.98421
%    2.04075
%
% a =
%
%    0.013084
%    0.106529
%
% ym =  0.16404
% aa =  9.3871
% bb =  0.12282
% s0 =  0.068892
% j =  1
% sr =  0.000061646
% r2 =  0.99911

% %% [markdown]
% ### Netwon Divided Difference

% %%
f = @(x) x;
X = [1 2 3 4];
Fx = arrayfun(f,X)
% Fx = [1 2 3 4]
% Out:
% Fx =
%
%    1   2   3   4

% %%
function dif = divided(i,k,X,Fx)
    if(i==k)
        dif = Fx(i);
    else
        dif = (divided(i+1,k,X,Fx) - divided(i,k-1,X,Fx))/(X(k)-X(i));
    end
end

% %%
divided(1,1,X,Fx)
% Out:
% ans =  1

% %% [markdown]
% ### Lagrange Polynomials
